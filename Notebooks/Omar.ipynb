# %%
import pandas as pd

# %%
# Importing my data
# TODO - get the raw link for the zip and extract to extract and use here. 
DATA_PATH_GENRE = 'https://raw.githubusercontent.com/Spotify-Song-Predict-DS18/Song-Predict/main/data/data_w_genres.csv'
DATA_PATH_GENRE_2 = 'https://raw.githubusercontent.com/Spotify-Song-Predict-DS18/Song-Predict/main/data/data_by_genres.csv'
DATA_PATH_ARTIST = 'https://raw.githubusercontent.com/Spotify-Song-Predict-DS18/Song-Predict/main/data/data_by_artist.csv'
DATA_PATH = 'https://raw.githubusercontent.com/Spotify-Song-Predict-DS18/Song-Predict/main/data/data.csv'
genres = pd.read_csv(DATA_PATH_GENRE)
genre2 = pd.read_csv(DATA_PATH_GENRE_2)
artist = pd.read_csv(DATA_PATH_ARTIST)
control = pd.read_csv(DATA_PATH)

# %%
genre2.head()
# Out:
#            genres  acousticness  danceability   duration_ms    energy  \
# 0           432hz      0.494780      0.299333  1.048887e+06  0.450678
# 1              []      0.679245      0.521473  2.298526e+05  0.401522
# 2      a cappella      0.621532      0.577017  1.936522e+05  0.345694
# 3        abstract      0.359395      0.459500  3.430185e+05  0.487000
# 4  abstract beats      0.353347      0.694400  2.338244e+05  0.613400
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.477762  0.131000 -16.854000     0.076817  120.285667  0.221750
# 1          0.196737  0.221586 -12.679076     0.112267  112.025168  0.515920
# 2          0.003799  0.127087 -12.770211     0.095324  111.813230  0.453186
# 3          0.791400  0.119480 -14.092000     0.043420  124.743200  0.304990
# 4          0.349403  0.102453  -6.699800     0.143453  119.398400  0.634187
#
#    popularity  key  mode
# 0   52.166667    5     1
# 1   21.682005    7     1
# 2   43.351819   11     1
# 3   41.500000    1     1
# 4   58.600000   10     0

# %%
artist.head()
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.575083
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.605444
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.442750  247260.000000  0.386336          0.022717  0.287708
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# 2      0.348286  328920.000000  0.286571          0.024593  0.325786
# 3      0.425074  262890.962963  0.245770          0.073587  0.275481
# 4      0.437333  232428.111111  0.429333          0.037534  0.216111
#
#     loudness  speechiness       tempo   valence  popularity  key  mode  count
# 0 -14.205417     0.180675  115.983500  0.334433   38.000000    5     1     12
# 1 -10.690000     0.176212  103.044154  0.268865   33.076923    5     1     26
# 2 -15.230714     0.118514   77.375857  0.354857   34.285714    0     1      7
# 3 -15.639370     0.123200   88.667630  0.372030   34.444444    0     1     27
# 4 -11.447222     0.086000  120.329667  0.458667   42.555556   11     1      9

# %%
control.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %%
control.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
control.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  169909.000000  169909.000000  1.699090e+05  169909.000000
# mean        0.493214       0.538150  2.314062e+05       0.488593
# std         0.376627       0.175346  1.213219e+05       0.267390
# min         0.000000       0.000000  5.108000e+03       0.000000
# 25%         0.094500       0.417000  1.710400e+05       0.263000
# 50%         0.492000       0.548000  2.086000e+05       0.481000
# 75%         0.888000       0.667000  2.629600e+05       0.710000
# max         0.996000       0.988000  5.403500e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  169909.000000     169909.000000  169909.000000  169909.000000
# mean        0.084863          0.161937       5.200519       0.206690
# std         0.278679          0.309329       3.515257       0.176796
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.000000          0.000000       2.000000       0.098400
# 50%         0.000000          0.000204       5.000000       0.135000
# 75%         0.000000          0.086800       8.000000       0.263000
# max         1.000000          1.000000      11.000000       1.000000
#
#             loudness           mode     popularity    speechiness  \
# count  169909.000000  169909.000000  169909.000000  169909.000000
# mean      -11.370289       0.708556      31.556610       0.094058
# std         5.666765       0.454429      21.582614       0.149937
# min       -60.000000       0.000000       0.000000       0.000000
# 25%       -14.470000       0.000000      12.000000       0.034900
# 50%       -10.474000       1.000000      33.000000       0.045000
# 75%        -7.118000       1.000000      48.000000       0.075400
# max         3.855000       1.000000     100.000000       0.969000
#
#                tempo        valence           year
# count  169909.000000  169909.000000  169909.000000
# mean      116.948017       0.532095    1977.223231
# std        30.726937       0.262408      25.593168
# min         0.000000       0.000000    1921.000000
# 25%        93.516000       0.322000    1957.000000
# 50%       114.778000       0.544000    1978.000000
# 75%       135.712000       0.749000    1999.000000
# max       244.091000       1.000000    2020.000000

# %%
control.shape
# Out:
# (169909, 19)

# %%
# Transforming my dataset
# TODO - Dates need to be coherent
# TODO - might have to make it into a function. 

control['release_date'] = pd.to_datetime(control['release_date'])

# Model crashes so taking out all music before 2010
mask = control['release_date'] >= '2020-1-1'
control = control[mask]

# %%
# Setting my X and Y values, we want to predict 5 songs that fit 
X = control.drop(['name', 'release_date'], axis=1)
y = control['name']

# %%
X.shape
# Out:
# (1756, 17)

# %%
from sklearn.model_selection import train_test_split

# Setting my X_train and y_train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, 
                                                    random_state=42)

# %%
# !pip install category_encoders
from category_encoders import OrdinalEncoder
from sklearn.linear_model import LogisticRegression
# Out:
# Requirement already satisfied: category_encoders in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (2.2.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from category_encoders) (1.5.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from category_encoders) (0.23.2)
# Requirement already satisfied: pandas>=0.21.1 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from category_encoders) (1.1.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from category_encoders) (1.19.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from category_encoders) (0.11.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from pandas>=0.21.1->category_encoders) (2020.1)
# Requirement already satisfied: six in c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)

# %%
X_train.head()
# Out:
#        acousticness                    artists  danceability  duration_ms  \
# 32145        0.2060       ['Rezz', 'Grabbitz']         0.644       198947
# 40167        0.0923               ['The 1975']         0.676       246445
# 32207        0.0326    ['Lil Uzi Vert', 'Syd']         0.619       181161
# 55596        0.4560  ['Pop Smoke', 'Lil Tjay']         0.683       160560
# 77983        0.0646           ['JayDaYoungan']         0.649       142000
#
#        energy  explicit                      id  instrumentalness  key  \
# 32145   0.349         0  4hR3hQKELrARHNZJ51D14s          0.000034    2
# 40167   0.661         0  3eeU7oRuEUbFHMrsJ8rvpk          0.007880    1
# 32207   0.784         1  5KlPy74NOEAt8jC3FYURnQ          0.000003    1
# 55596   0.799         1  5eJpwQyirY5EEdNadHKRAM          0.000000    1
# 77983   0.501         1  0nb31l6np6ud0RATN4UQ1u          0.000000    4
#
#        liveness  loudness  mode  popularity  speechiness    tempo  valence  \
# 32145    0.1250    -5.315     0          66       0.0364   94.971    0.246
# 40167    0.1020    -8.909     1          66       0.0481  105.006    0.145
# 32207    0.3150    -6.110     1          63       0.1230  156.035    0.471
# 55596    0.2640    -5.923     1          65       0.3000  145.128    0.752
# 77983    0.0888   -10.005     0          51       0.2040  129.805    0.144
#
#        year
# 32145  2020
# 40167  2020
# 32207  2020
# 55596  2020
# 77983  2020

# %%
# Fitting a baseline model that will return 5 songs to recommend 
encoder = OrdinalEncoder(cols=['artists', 'id']) 

# Setting my transformed Feature Matrix
XT_train = encoder.fit_transform(X_train)
XT_test = encoder.fit_transform(X_test)

# Instantiating my baseline model
model = LogisticRegression()

# Fitting on my transformed data
model.fit(XT_train, y_train)
# Out:
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Looking at the head of my XT_train to see how it looks 
XT_train.head()
# Out:
#        acousticness  artists  danceability  duration_ms  energy  explicit  id  \
# 32145        0.2060        1         0.644       198947   0.349         0   1
# 40167        0.0923        2         0.676       246445   0.661         0   2
# 32207        0.0326        3         0.619       181161   0.784         1   3
# 55596        0.4560        4         0.683       160560   0.799         1   4
# 77983        0.0646        5         0.649       142000   0.501         1   5
#
#        instrumentalness  key  liveness  loudness  mode  popularity  \
# 32145          0.000034    2    0.1250    -5.315     0          66
# 40167          0.007880    1    0.1020    -8.909     1          66
# 32207          0.000003    1    0.3150    -6.110     1          63
# 55596          0.000000    1    0.2640    -5.923     1          65
# 77983          0.000000    4    0.0888   -10.005     0          51
#
#        speechiness    tempo  valence  year
# 32145       0.0364   94.971    0.246  2020
# 40167       0.0481  105.006    0.145  2020
# 32207       0.1230  156.035    0.471  2020
# 55596       0.3000  145.128    0.752  2020
# 77983       0.2040  129.805    0.144  2020

# %%
pred = model.predict(XT_test)

# %%
pred
# Out:
# array(['Hardest To Love', 'Circles', 'Blanche', 'Know Your Worth',
#        'Same Thing', 'Toosie Slide', 'Blanche', 'Hardest To Love',
#        'Blanche', 'Element', 'Blanche', 'Same Thing', 'Same Thing',
#        'Same Thing', 'Hardest To Love', 'Hardest To Love', 'Same Thing',
#        'Hardest To Love', 'Same Thing', 'Toosie Slide', 'Blanche',
#        'Circles', 'Toosie Slide', 'Blanche', 'Hardest To Love', 'Blanche',
#        'Blanche', 'Same Thing', 'Balir Shohor Female', 'Element',
#        'Hardest To Love', 'Forever (feat. Lil Wayne)', 'Toosie Slide',
#        'Hardest To Love', 'Same Thing', 'Circles', 'Hardest To Love',
#        'Blanche', 'Hardest To Love', 'Hardest To Love', 'Circles',
#        'Otherside Of America', 'Hardest To Love', 'Element',
#        'Big Slimes (feat. Gunna & Lil Duke)', 'Hardest To Love',
#        'Forever (feat. Lil Wayne)', '19.10', 'Otherside Of America',
#        'Hardest To Love', 'Hardest To Love', 'Know Your Worth',
#        'Hardest To Love', 'Blanche', 'Know Your Worth', 'Hardest To Love',
#        'Blanche', 'Hardest To Love', 'Toosie Slide',
#        'Forever (feat. Lil Wayne)', 'Hardest To Love', 'Blanche',
#        'Hardest To Love', 'Otherside Of America', 'Blanche', 'Blanche',
#        'Otherside Of America', 'Hardest To Love', 'Blanche',
#        'Hardest To Love', 'Circles', 'Hardest To Love', 'Circles',
#        'Hardest To Love', 'Forever (feat. Lil Wayne)', 'Blanche',
#        'Hardest To Love', 'Same Thing', 'Forever (feat. Lil Wayne)',
#        'Blanche', 'Circles', 'Hardest To Love', 'Hardest To Love',
#        'Blanche', 'Same Thing', 'Hardest To Love', 'Blanche', 'Good Day',
#        'Big Slimes (feat. Gunna & Lil Duke)', 'Same Thing', 'Blanche',
#        'Same Thing', 'Blanche', 'Toosie Slide', 'Same Thing',
#        'Hardest To Love', 'Toosie Slide', 'Same Thing', 'Circles',
#        'Hardest To Love', 'Toosie Slide', 'Circles', 'Toosie Slide',
#        'Hardest To Love', 'Toosie Slide', 'Know Your Worth',
#        'Toosie Slide', 'Blanche', 'Same Thing', 'Same Thing',
#        'Toosie Slide', 'Blanche', 'Circles', 'Toosie Slide', 'Blanche',
#        'Lotto', 'Hardest To Love', 'Hardest To Love', 'Toosie Slide',
#        'Hardest To Love', 'Blanche', 'Same Thing', 'Toosie Slide',
#        'Toosie Slide', 'Circles', 'Same Thing', 'Blanche', 'Element',
#        'Blanche', 'Hardest To Love', 'Blanche', 'Hardest To Love',
#        'Otherside Of America', 'Same Thing', 'Otherside Of America',
#        'Blanche', 'Hardest To Love', 'Hardest To Love', 'Blanche',
#        'Circles', 'Lotto', 'Otherside Of America', 'Hardest To Love',
#        'Know Your Worth', 'Circles', 'Toosie Slide', 'Toosie Slide',
#        'Same Thing', 'Toosie Slide', 'Same Thing', 'Hardest To Love',
#        'Hardest To Love', 'Blanche', 'Circles', 'Same Thing',
#        'Otherside Of America', 'Know Your Worth', 'Hardest To Love',
#        'Blanche', 'Hardest To Love', 'Hardest To Love', 'Toosie Slide',
#        'Toosie Slide', 'Blanche', 'Blanche', 'Same Thing',
#        'Hardest To Love', 'Same Thing', 'Blanche', 'Hardest To Love',
#        'Blanche', 'Same Thing', 'Toosie Slide',
#        'Forever (feat. Lil Wayne)', 'Hardest To Love',
#        'Otherside Of America', 'Toosie Slide', 'Otherside Of America',
#        'Hardest To Love', 'Blanche', 'Toosie Slide', 'Blanche',
#        'Hardest To Love', 'Blanche', 'Hardest To Love', 'Same Thing',
#        'Blanche', 'Big Slimes (feat. Gunna & Lil Duke)',
#        'Know Your Worth', 'Hardest To Love', 'Escape From LA', 'Lotto',
#        'Hardest To Love', 'Toosie Slide', 'Hardest To Love',
#        'Contador de Reencontros - Ao Vivo', 'Toosie Slide',
#        'Toosie Slide', 'Hardest To Love', 'Hardest To Love',
#        'Y Hubo Alguien', 'Forever (feat. Lil Wayne)', 'Hardest To Love',
#        'Circles', 'Same Thing', 'Toosie Slide', 'Hardest To Love',
#        'Hardest To Love', 'Circles', 'Otherside Of America', 'Blanche',
#        'Blanche', 'Blanche', 'Blanche', 'Hardest To Love',
#        'Hardest To Love', 'Hardest To Love', 'Circles', 'Hardest To Love',
#        'Blanche', 'Forever (feat. Lil Wayne)', 'Blanche', 'Same Thing',
#        'Big Slimes (feat. Gunna & Lil Duke)', 'Toosie Slide', 'Blanche',
#        'Hardest To Love', 'Circles', 'Otherside Of America', 'Blanche',
#        'Same Thing', 'Same Thing', 'Hardest To Love', 'Hardest To Love',
#        'Circles', 'Blanche', 'Hardest To Love', 'Circles', 'Same Thing',
#        'Hardest To Love', 'Blanche', 'Hardest To Love', 'Hardest To Love',
#        'Toosie Slide', 'Hardest To Love', 'Otherside Of America',
#        'Blanche', 'Hardest To Love', 'Same Thing', 'Same Thing',
#        'Hardest To Love', 'Hardest To Love', 'Hardest To Love',
#        'Hardest To Love', 'Circles', 'Same Thing', 'Toosie Slide',
#        'Hardest To Love', 'Hardest To Love', 'Toosie Slide', 'Element',
#        'Toosie Slide', 'Toosie Slide', 'Hardest To Love',
#        'Hardest To Love', 'Hardest To Love', 'Toosie Slide',
#        'Hardest To Love', 'Same Thing', 'Toosie Slide', 'Know Your Worth',
#        'Blanche', 'Hardest To Love', 'Hardest To Love', 'Hardest To Love',
#        'Hardest To Love', 'Otherside Of America', 'Hardest To Love',
#        'Blanche', 'Hardest To Love', 'Blanche', 'Hardest To Love',
#        'Blanche', 'Hardest To Love', 'Same Thing', 'Hardest To Love',
#        'Hardest To Love', 'Blanche', 'Toosie Slide', 'Hardest To Love',
#        'Same Thing', 'Toosie Slide', 'Same Thing', 'Hardest To Love',
#        'Blanche', 'Element', 'Circles', 'Know Your Worth',
#        'Hardest To Love', 'Otherside Of America', 'Same Thing',
#        'Hardest To Love', 'Toosie Slide', 'Hardest To Love',
#        'Hardest To Love', 'Forever (feat. Lil Wayne)', 'Blanche',
#        'Big Slimes (feat. Gunna & Lil Duke)', 'Hardest To Love',
#        'Escape From LA', 'Same Thing', 'Hardest To Love',
#        'Forever (feat. Lil Wayne)', 'Circles', 'Blanche', 'Blanche',
#        'Blanche', 'Hardest To Love', 'Hardest To Love', 'Toosie Slide',
#        'Hardest To Love', 'Blanche', 'Hardest To Love', 'Blanche',
#        'Same Thing', 'Toosie Slide', 'Know Your Worth', 'Toosie Slide',
#        'Hardest To Love', 'Blanche', 'Otherside Of America',
#        'Big Slimes (feat. Gunna & Lil Duke)', 'Hardest To Love',
#        'Same Thing', 'Circles', 'Circles', 'Know Your Worth',
#        'Toosie Slide', 'Same Thing', 'Same Thing', 'Lotto', 'Blanche',
#        'Blanche', 'Hardest To Love', 'Toosie Slide', 'Hardest To Love',
#        'Blanche', 'Hardest To Love', 'Blanche', 'Hardest To Love',
#        'Toosie Slide', 'Toosie Slide', 'Same Thing', 'Toosie Slide',
#        'Hardest To Love', 'Otherside Of America', 'Hardest To Love',
#        'Toosie Slide', 'Blanche', 'Element', 'Blanche', 'Toosie Slide',
#        'Blanche', 'Toosie Slide', 'Forever (feat. Lil Wayne)',
#        'Know Your Worth', 'Same Thing', 'Blanche', 'Circles',
#        'Hardest To Love', 'Toosie Slide', 'Blanche',
#        'Forever (feat. Lil Wayne)', 'Toosie Slide', 'Toosie Slide',
#        'Toosie Slide', 'Hardest To Love', 'Toosie Slide', 'Blanche',
#        'Same Thing', 'Circles', 'Blanche', 'Hardest To Love',
#        'Hardest To Love', 'Same Thing', 'Hardest To Love',
#        'Otherside Of America', 'Riot',
#        'Deeper Love - Pedro Henriques Remix', 'Toosie Slide',
#        'Toosie Slide', 'Hardest To Love', 'Same Thing', 'Same Thing',
#        'Blanche', 'Hardest To Love', 'Escape From LA', 'Hardest To Love',
#        'Hardest To Love', 'Blanche', 'Toosie Slide',
#        'Forever (feat. Lil Wayne)', 'Know Your Worth', 'Blanche',
#        'Hardest To Love', 'Toosie Slide', 'Hardest To Love',
#        'Hardest To Love', 'Hardest To Love', 'Six Feet Apart',
#        'Hardest To Love', 'Otherside Of America', 'Hardest To Love',
#        'Same Thing', 'Toosie Slide', 'Blanche', 'Good Day', 'Same Thing',
#        'Hardest To Love', 'Same Thing', 'Hardest To Love', 'Blanche',
#        'Same Thing', 'Hardest To Love', 'Otherside Of America',
#        'Hardest To Love', 'Toosie Slide', 'Same Thing', 'Toosie Slide',
#        'Blanche', 'Same Thing', 'Circles', 'Hardest To Love',
#        'Hardest To Love', 'Blanche', 'Blanche', 'Hardest To Love',
#        'Forever (feat. Lil Wayne)', 'Blanche', 'Blanche',
#        'Hardest To Love', 'Riot', 'Escape From LA', 'Same Thing',
#        'Blanche', 'Lotto', 'Blanche', 'Lose Somebody', 'Hardest To Love',
#        'Invincible', 'Hardest To Love', 'Hardest To Love',
#        'Hardest To Love', 'Same Thing', 'Blanche', 'Toosie Slide',
#        'Circles', 'Same Thing', 'Hardest To Love',
#        'Big Slimes (feat. Gunna & Lil Duke)', 'Toosie Slide',
#        'Hardest To Love', 'Toosie Slide', 'Toosie Slide',
#        'Hardest To Love', 'Toosie Slide', 'Hardest To Love',
#        'Otherside Of America', 'Same Thing', 'Same Thing',
#        'Hardest To Love', 'Hardest To Love', 'Blanche', 'Toosie Slide',
#        'Same Thing', 'Element', 'Same Thing', 'Hardest To Love',
#        'Same Thing', 'Element', 'Same Thing', 'Otherside Of America',
#        'Hardest To Love', 'Same Thing', 'Six Feet Apart', 'Good Day',
#        'Blanche', 'Lotto', 'Big Slimes (feat. Gunna & Lil Duke)',
#        'Hardest To Love', 'Blanche', 'Otherside Of America', 'Same Thing',
#        'Blanche', 'Toosie Slide', 'Hardest To Love', 'Know Your Worth',
#        'Same Thing', 'Hardest To Love', 'Escape From LA',
#        'Hardest To Love', 'Know Your Worth', 'Hardest To Love',
#        'Know Your Worth', 'Element', 'Toosie Slide', 'Same Thing',
#        'Otherside Of America', 'Circles', 'Same Thing', 'Blanche',
#        'Blanche', 'Otherside Of America', 'Blanche', 'Hardest To Love',
#        'Toosie Slide', 'Hardest To Love', 'Hardest To Love', 'Same Thing',
#        'Blanche', 'Hardest To Love', 'Toosie Slide', 'Blanche',
#        'Big Slimes (feat. Gunna & Lil Duke)', 'Hardest To Love',
#        'Toosie Slide', 'Hardest To Love', 'Otherside Of America',
#        'Hardest To Love', 'Hardest To Love', 'Blanche',
#        'Forever (feat. Lil Wayne)', 'Hardest To Love', 'Same Thing',
#        'Forever (feat. Lil Wayne)', 'Toosie Slide', 'Hardest To Love',
#        'Hardest To Love', 'Blanche', 'Hardest To Love', 'Blanche',
#        'Six Feet Apart', 'Same Thing', 'Hardest To Love', 'Same Thing',
#        'Hardest To Love', 'Know Your Worth', 'Blanche', 'Toosie Slide',
#        'Escape From LA', 'Hardest To Love', 'Know Your Worth', 'Circles',
#        'Hardest To Love', 'Toosie Slide', 'Same Thing', 'Hardest To Love',
#        'Blanche', 'Same Thing', 'Toosie Slide', 'Hardest To Love',
#        'Know Your Worth', 'Toosie Slide', 'Know Your Worth',
#        'Hardest To Love', 'Hardest To Love', 'Forever (feat. Lil Wayne)',
#        'Hardest To Love', 'Hardest To Love', 'Hardest To Love', 'Circles',
#        'Same Thing', 'Hardest To Love', 'Toosie Slide', 'Know Your Worth',
#        'Hardest To Love', 'Blanche', 'Same Thing', 'Hardest To Love',
#        'Hardest To Love', 'Circles', 'Hardest To Love',
#        'Contador de Reencontros - Ao Vivo', 'Hardest To Love', 'Circles',
#        'Toosie Slide', 'Hardest To Love', 'Know Your Worth', 'Blanche',
#        'Same Thing', 'Riot', 'Hardest To Love', 'Circles', 'Blanche',
#        'Hardest To Love', 'Toosie Slide', 'Blanche', 'Blanche',
#        'Hardest To Love', 'Toosie Slide', 'Blanche', 'Lotto',
#        'Big Slimes (feat. Gunna & Lil Duke)', 'Same Thing',
#        '12.38 (feat. 21 Savage, Ink & Kadhja Bonet)', 'Circles',
#        'Toosie Slide', 'Hardest To Love', 'Hardest To Love',
#        'Hardest To Love', 'Circles',
#        '12.38 (feat. 21 Savage, Ink & Kadhja Bonet)', 'Same Thing',
#        'Hardest To Love', 'Toosie Slide'], dtype=object)

# %%
# TODO- Find a way to input the name and artist of song, then have it translate to data
# The model can read happily to make a prediction

# TODO - Make sure the model returns 5 different songs based on one input.

# %%
def put_in_pred(song):
    # Take the song name and match it to the location of the song in the y
    # Then take it with the artist and match it with the row that it is on the XT_train
    # Then we would fit the song into the model and it will pop out 5 different songs 
    # are similar in nature 
    
    # Creating the mask that will grab the location of the song name
    mask = (y == song)
    yt = y[mask]
    # returns the index locaiton
    yti = list(yt.index)
    yti = yti[0]
    # Now that we have the location of the song we can now match it where 
    # it would be in the X dataframe
    Xt = X.loc[yti]
    Xt = pd.DataFrame(Xt)
    # This returns the row where the song is actually at
    mask = list(Xt.columns)
    Xt = X.loc[mask]
    # Now I have to encode it 
    Xt = encoder.fit_transform(Xt)
    # Now that we have the list of the item, time to run it through the model 
    pred = model.predict(Xt)
    
    
    return pred

# %%
#Running a test 
song = 'Circles'
artist = 'Mac Miller'
put_in_pred(song)
# Out:
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# array(['Contador de Reencontros - Ao Vivo'], dtype=object)

# %%
# Now making a function that will take a prediction and return 4 more
def top_five(song):
    song = put_in_pred(song)
    print(song)
    for i in range (0,4):
        song_to_str = ""
        for ele in song:
            song_to_str += ele
        song = put_in_pred(song_to_str)
        print(song)

# %%
top_five(song)
# Out:
# ['Contador de Reencontros - Ao Vivo']
# ['Be Alright']
# ['Hardest To Love']
# ['Hardest To Love']
# ['Hardest To Love']
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
