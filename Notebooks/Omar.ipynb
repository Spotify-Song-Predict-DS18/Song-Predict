# %%
import pandas as pd

# %%
# Importing my data
# TODO - get the raw link for the zip and extract to extract and use here. 
DATA_PATH_GENRE = 'https://raw.githubusercontent.com/Spotify-Song-Predict-DS18/Song-Predict/main/data/data_w_genres.csv'
DATA_PATH_GENRE_2 = 'https://raw.githubusercontent.com/Spotify-Song-Predict-DS18/Song-Predict/main/data/data_by_genres.csv'
DATA_PATH_ARTIST = 'https://raw.githubusercontent.com/Spotify-Song-Predict-DS18/Song-Predict/main/data/data_by_artist.csv'
DATA_PATH = 'https://raw.githubusercontent.com/Spotify-Song-Predict-DS18/Song-Predict/main/data/data.csv'
genres = pd.read_csv(DATA_PATH_GENRE)
genre2 = pd.read_csv(DATA_PATH_GENRE_2)
artist = pd.read_csv(DATA_PATH_ARTIST)
control = pd.read_csv(DATA_PATH)

# %%
genre2.head()
# Out:
#            genres  acousticness  danceability   duration_ms    energy  \
# 0           432hz      0.494780      0.299333  1.048887e+06  0.450678
# 1              []      0.679245      0.521473  2.298526e+05  0.401522
# 2      a cappella      0.621532      0.577017  1.936522e+05  0.345694
# 3        abstract      0.359395      0.459500  3.430185e+05  0.487000
# 4  abstract beats      0.353347      0.694400  2.338244e+05  0.613400
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.477762  0.131000 -16.854000     0.076817  120.285667  0.221750
# 1          0.196737  0.221586 -12.679076     0.112267  112.025168  0.515920
# 2          0.003799  0.127087 -12.770211     0.095324  111.813230  0.453186
# 3          0.791400  0.119480 -14.092000     0.043420  124.743200  0.304990
# 4          0.349403  0.102453  -6.699800     0.143453  119.398400  0.634187
#
#    popularity  key  mode
# 0   52.166667    5     1
# 1   21.682005    7     1
# 2   43.351819   11     1
# 3   41.500000    1     1
# 4   58.600000   10     0

# %%
artist.head()
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.575083
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.605444
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.442750  247260.000000  0.386336          0.022717  0.287708
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# 2      0.348286  328920.000000  0.286571          0.024593  0.325786
# 3      0.425074  262890.962963  0.245770          0.073587  0.275481
# 4      0.437333  232428.111111  0.429333          0.037534  0.216111
#
#     loudness  speechiness       tempo   valence  popularity  key  mode  count
# 0 -14.205417     0.180675  115.983500  0.334433   38.000000    5     1     12
# 1 -10.690000     0.176212  103.044154  0.268865   33.076923    5     1     26
# 2 -15.230714     0.118514   77.375857  0.354857   34.285714    0     1      7
# 3 -15.639370     0.123200   88.667630  0.372030   34.444444    0     1     27
# 4 -11.447222     0.086000  120.329667  0.458667   42.555556   11     1      9

# %%
control.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %%
control.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
control.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  169909.000000  169909.000000  1.699090e+05  169909.000000
# mean        0.493214       0.538150  2.314062e+05       0.488593
# std         0.376627       0.175346  1.213219e+05       0.267390
# min         0.000000       0.000000  5.108000e+03       0.000000
# 25%         0.094500       0.417000  1.710400e+05       0.263000
# 50%         0.492000       0.548000  2.086000e+05       0.481000
# 75%         0.888000       0.667000  2.629600e+05       0.710000
# max         0.996000       0.988000  5.403500e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  169909.000000     169909.000000  169909.000000  169909.000000
# mean        0.084863          0.161937       5.200519       0.206690
# std         0.278679          0.309329       3.515257       0.176796
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.000000          0.000000       2.000000       0.098400
# 50%         0.000000          0.000204       5.000000       0.135000
# 75%         0.000000          0.086800       8.000000       0.263000
# max         1.000000          1.000000      11.000000       1.000000
#
#             loudness           mode     popularity    speechiness  \
# count  169909.000000  169909.000000  169909.000000  169909.000000
# mean      -11.370289       0.708556      31.556610       0.094058
# std         5.666765       0.454429      21.582614       0.149937
# min       -60.000000       0.000000       0.000000       0.000000
# 25%       -14.470000       0.000000      12.000000       0.034900
# 50%       -10.474000       1.000000      33.000000       0.045000
# 75%        -7.118000       1.000000      48.000000       0.075400
# max         3.855000       1.000000     100.000000       0.969000
#
#                tempo        valence           year
# count  169909.000000  169909.000000  169909.000000
# mean      116.948017       0.532095    1977.223231
# std        30.726937       0.262408      25.593168
# min         0.000000       0.000000    1921.000000
# 25%        93.516000       0.322000    1957.000000
# 50%       114.778000       0.544000    1978.000000
# 75%       135.712000       0.749000    1999.000000
# max       244.091000       1.000000    2020.000000

# %%
# Transforming my dataset
# TODO - Dates need to be coherent
# TODO - might have to make it into a function. 

control['release_date'] = pd.to_datetime(control['release_date'])
# Out:
#   File "<ipython-input-42-61a20d717a6a>", line 5
#     control['release_date'] = pd.to_datetime(control['release_date'])
#     ^
# IndentationError: unexpected indent

# %%
# Setting my X and Y values, we want to predict 5 songs that fit 
X = control.drop(['name', 'release_date'], axis=1)
y = control['name']

# %%
from sklearn.model_selection import train_test_split

# Setting my X_train and y_train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, 
                                                    random_state=42)

# %%
from category_encoders import OrdinalEncoder
from sklearn.linear_model import LogisticRegression

# %%
X_train.head()
# Out:
#         acousticness                                        artists  \
# 68705         0.5590                         ['El Poder Del Norte']
# 71977         0.7710                                ['Ray Conniff']
# 64923         0.8080  ['Columbia Studio Orchestra', 'Johnny Green']
# 118204        0.7290                           ['Эрнест Хемингуэй']
# 106136        0.0461                                   ['Arcangel']
#
#         danceability  duration_ms  energy  explicit                      id  \
# 68705          0.704       228360  0.5180         0  3tDNehzGbZMsOh1iTzaCbE
# 71977          0.377       194333  0.3230         0  0Jp5gEvPwFYM0xsSAFtQaw
# 64923          0.387       217520  0.6490         0  7iNm6OATVHr2flUP6W64qA
# 118204         0.723        95600  0.0722         1  0rxqF2L1x0O4F3ttrQESe7
# 106136         0.564       234027  0.6840         0  2BrfJdTXohQRtWBKsBTIp0
#
#         instrumentalness  key  liveness  loudness  mode  popularity  \
# 68705           0.000000    9     0.106    -9.500     1          46
# 71977           0.523000    2     0.252   -12.386     1          13
# 64923           0.007670    9     0.671   -10.814     1          10
# 118204          0.000000   11     0.415   -20.133     0           0
# 106136          0.000718    7     0.335    -4.719     0          63
#
#         speechiness    tempo  valence  year
# 68705        0.0487   79.113    0.884  2001
# 71977        0.0340  121.841    0.357  1960
# 64923        0.1550  134.145    0.352  1963
# 118204       0.9470  118.094    0.600  1940
# 106136       0.0348  119.990    0.404  2008

# %%
# Fitting a baseline model that will return 5 songs to recommend 
encoder = OrdinalEncoder(cols=['artists', 'id']) 

# Setting my transformed Feature Matrix
XT_train = encoder.fit_transform(X_train)
XT_test = encoder.fit_transform(X_test)

# Instantiating my baseline model
model = LogisticRegression()

# Fitting on my transformed data
model.fit(XT_train, y_train)
# Out:
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-ea522a22cf1e> in <module>
#      10
#      11 # Fitting on my transformed data
# ---> 12 model.fit(XT_train, y_train)
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1405         else:
#    1406             prefer = 'processes'
# -> 1407         fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#    1408                                **_joblib_parallel_args(prefer=prefer))(
#    1409             path_func(X, y, pos_class=class_, Cs=[C_],
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     686         if solver not in ['sag', 'saga']:
#     687             lbin = LabelBinarizer()
# --> 688             Y_multi = lbin.fit_transform(y)
#     689             if Y_multi.shape[1] == 1:
#     690                 Y_multi = np.hstack([1 - Y_multi, Y_multi])
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\sklearn\preprocessing\_label.py in fit_transform(self, y)
#     458             Shape will be [n_samples, 1] for binary problems.
#     459         """
# --> 460         return self.fit(y).transform(y)
#     461
#     462     def transform(self, y):
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\sklearn\preprocessing\_label.py in transform(self, y)
#     486                              " input.")
#     487
# --> 488         return label_binarize(y, classes=self.classes_,
#     489                               pos_label=self.pos_label,
#     490                               neg_label=self.neg_label,
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\sklearn\preprocessing\_label.py in label_binarize(y, classes, neg_label, pos_label, sparse_output)
#     661
#     662         # pick out the known labels from y
# --> 663         y_in_classes = np.in1d(y, classes)
#     664         y_seen = y[y_in_classes]
#     665         indices = np.searchsorted(sorted_class, y_seen)
#
# <__array_function__ internals> in in1d(*args, **kwargs)
#
# c:\users\zaffa\.virtualenvs\build_week-ajwi7e3u\lib\site-packages\numpy\lib\arraysetops.py in in1d(ar1, ar2, assume_unique, invert)
#     578             mask = np.zeros(len(ar1), dtype=bool)
#     579             for a in ar2:
# --> 580                 mask |= (ar1 == a)
#     581         return mask
#     582
#
# KeyboardInterrupt:

# %%
model.score(XT_test, y_test)
